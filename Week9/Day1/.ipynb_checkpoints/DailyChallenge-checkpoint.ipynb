# %% [markdown]
# # Daily Challenge: Prompt Engineering With ChatGPT

# %% [markdown]
# ## Exercise
# Identify Key Topics: List 3 key points you want to explore related to e-commerce and consumers trends.
#
# Craft Prompts: Create prompts for ChatGPT to gather information on these topics.
#
# Gather Responses: Use ChatGPT to execute these prompts and collect data.
#
# Plan Presentation: Outline how you will present these findings.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings; warnings.filterwarnings(action = 'ignore')
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Loading the dataset 
file_path = r'C:\Users\Acer\Desktop\shopping_behavior_updated.csv'
df = pd.read_csv(file_path) 

df.info()
<div style="border:solid green 2px; padding: 20px">
   df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# **Key Topics:**
#
# - 1. Consumer Purchase Behavior:
# Explore the factors influencing consumer purchase decisions.
# Understand preferences in product categories, payment methods, and shipping choices.
#
#
# - 2. Customer Satisfaction and Reviews:
# Analyze customer reviews and ratings.
# Identify common themes in positive and negative feedback.
#
# - 3. Subscription Trends:
# Investigate the frequency and popularity of subscription-based purchases.
# Understand customer preferences for subscription plans.
#
# **Prompts:**
#
# - 1. Consumer Purchase Behavior:
# "Describe the most popular product categories among online shoppers in recent trends."
# "What factors contribute to customers choosing specific payment methods and shipping options?"
#
# - 2. Customer Satisfaction and Reviews:
# "Analyze customer reviews for clothing items. What are the common positive sentiments?"
# "Identify recurring issues or concerns mentioned in customer reviews for footwear products."
#
# - 3. Subscription Trends:
# "Explore the frequency of subscription-based purchases in the dataset. Are there any emerging patterns?"
# "What are the primary reasons customers choose subscription plans, and which plans are most preferred?"
#
# **Plan Presentation:**
#
# - Introduction:
# Brief overview of the e-commerce dataset.
# Mention the significance of understanding consumer trends.
#
# - Consumer Purchase Behavior:
# Present insights on popular product categories.
# Discuss findings on payment method and shipping preferences.
#
# - Customer Satisfaction and Reviews:
# Highlight positive sentiments from clothing reviews.
# Address common concerns in footwear reviews.
#
# - Subscription Trends:
# Showcase the frequency and patterns of subscription purchases.
# Discuss reasons behind choosing subscription plans and their popularity.
#
# - Conclusion:
# Summarize key findings.
# Discuss potential implications for the e-commerce business.

# %% [markdown]
# ## Next Day Presentation:
# Create a short presentation (<10 min) that should include the following sections:
#
# Introduction: Brief introduction to e-commerce trends.
# Body: Detailed discussion on consumer trends, AI applications, and challenges.
# Conclusion: Summarize key findings and potential future trends.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# **Slide 1: Introduction to E-commerce Trends**
#
# Title: "Navigating the E-commerce Landscape"
# Brief Overview:
# E-commerce has witnessed rapid evolution in recent years.
# Introduction to the dataset and its relevance.
# Importance of understanding trends for business success.
#
# **Slide 2: Consumer Trends in E-commerce**
#
# Title: "Understanding Consumer Behavior"
# Key Points:
# Popular product categories and emerging trends.
# Factors influencing purchase decisions.
# Insights into preferred payment methods and shipping options.
#
# **Slide 3: AI Applications in E-commerce**
#
# Title: "Revolutionizing E-commerce with AI"
# Key Points:
# Role of AI in personalizing user experiences.
# AI-driven product recommendations and their impact.
# Enhancements in customer support and chatbots.
#
# **Slide 4: Challenges in E-commerce**
#
# Title: "Navigating Challenges in the Digital Realm"
# Key Challenges:
# Security and privacy concerns.
# Balancing personalization without intrusiveness.
# Addressing the digital divide and accessibility.
#
# **Slide 5: Conclusion**
#
# Title: "Key Takeaways and Future Outlook"
# Summary:
# Recap of consumer trends and AI applications.
# Highlighting challenges and potential solutions.
# Encouragement for adapting to future trends.
#
# **Slide 6: Q&A Session**
#
# Title: "Engage with Your Questions"
# Inviting questions from the audience.
# Encouraging a discussion on presented topics.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# **Slide 1: Introduction to E-commerce Trends**
#
# Good morning everyone! Today, we embark on a journey through the dynamic landscape of e-commerce, exploring the latest trends that shape the digital marketplace. In our exploration, we'll dive into a dataset that encapsulates the pulse of consumer behavior, offering insights crucial for adapting to this ever-evolving ecosystem.
#
# **Slide 2: Consumer Trends in E-commerce**
#
# As we unfold the layers of consumer behavior, we encounter fascinating patterns and preferences. From trending product categories to the factors that guide purchase decisions, we'll unravel the intricacies of how consumers interact with the digital marketplace. Moreover, we'll explore the preferred payment methods and shipping options that significantly influence the overall e-commerce experience.
#
# **Slide 3: AI Applications in E-commerce**
#
# Artificial Intelligence is a transformative force in e-commerce, acting as a catalyst for personalized user experiences. We'll delve into the applications of AI, from intelligent product recommendations that enhance customer satisfaction to the integration of AI-driven chatbots revolutionizing customer support. Get ready to witness how technology is reshaping the way we shop.
#
# **Slide 4: Challenges in E-commerce**
#
# However, this journey is not without its challenges. Today, we confront issues of security, privacy, and the delicate balance between personalization and intrusion. We'll discuss how the digital realm grapples with the digital divide, ensuring accessibility for all. Join us in navigating these challenges as we envision a more inclusive and secure e-commerce landscape.
#
# **Slide 5: Conclusion**
#
# In conclusion, we recap the key takeaways from our expedition. We'll reflect on the consumer trends shaping the market, the transformative power of AI, and the challenges that demand our attention. As we bid farewell, we'll peer into the future, offering a glimpse of what lies ahead in the world of e-commerce.
#
# **Slide 6: Q&A Session**
#
# Now, the floor is yours! We invite your questions, thoughts, and insights. Let's engage in a meaningful discussion about the trends, challenges, and possibilities in the world of e-commerce.
